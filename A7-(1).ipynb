# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A51L33/B52_PfDS/blob/main/A7-(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Year': [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020],
    'Population': [2.5, 3.0, 3.7, 4.4, 5.3, 6.1, 6.9, 7.8]
}
df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Population'], marker='o', linestyle='-', color='teal')
plt.title('World Population Growth Over Decades')
plt.xlabel('Year')
plt.ylabel('Population (Billions)')
plt.grid(True)
plt.tight_layout()
plt.show()
